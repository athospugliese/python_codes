# %% [markdown]
# <a href="https://colab.research.google.com/github/athospugliesedev/python_codes/blob/main/Lista_6_Pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Junto com esta lista do Jupyter, a base de dados "data_pandas.csv" vai ser fundamental para realizar os exercícios a seguir.

# %% [markdown]
# ### 1) O arquivo "data_pandas.csv" é uma base de dados com preços históricos das vendas da empresa de supermercado que registrou dados em 3 filiais diferentes por 3 meses.

# %% [markdown]
# 1.   Item da lista
# 2.   Item da lista

# %% [markdown]
# #### a) Inicialmente, precisamos importar o Pandas para nosso código e armazenar os dados contidos no arquivo "data_pandas.csv" dentro de uma variável

# %%
import pandas as pd
from google.colab import drive

# Monta o Google Drive
drive.mount('/content/drive')

# Especifique o caminho para o arquivo CSV no Google Drive
file_path = '/content/drive/My Drive/dataset/data_pandas.csv'

# Carrega o arquivo CSV usando o Pandas
df = pd.read_csv(file_path)

# Exibe as primeiras linhas do DataFrame
print(df.head())
# Out:
# Mounted at /content/drive
#             ID Filial     Cidade Tipo cliente  Genero       Linha produto  \
# 0  319-50-3348      B   Mandalay       Normal  Female  Home and lifestyle
# 1  390-80-5128      B   Mandalay       Member  Female   Health and beauty
# 2  523-38-0215      C  Naypyitaw       Normal    Male  Home and lifestyle
# 3  565-91-4567      B   Mandalay       Normal    Male   Health and beauty
# 4  829-34-3910      A     Yangon       Normal  Female   Health and beauty
#
#    Preco unitario  Quantidade  Taxa 5%     Total       Data   Hora  \
# 0           40.30           2   4.0300   84.6300  3/11/2019  15:30
# 1           19.15           1   0.9575   20.1075  1/28/2019  17:58
# 2           37.00           1   1.8500   38.8500   3/6/2019  13:29
# 3           10.75           8   4.3000   90.3000  3/15/2019  14:38
# 4           71.38          10  35.6900  749.4900  3/29/2019  19:21
#
#   Forma pagamento  Custo produto vendido  Margem bruta  Receita bruta  Rating
# 0         Ewallet                  80.60      4.761905         4.0300     4.4
# 1     Credit card                  19.15      4.761905         0.9575     9.5
# 2     Credit card                  37.00      4.761905         1.8500     7.9
# 3         Ewallet                  86.00      4.761905         4.3000     6.2
# 4            Cash                 713.80      4.761905        35.6900     5.7

# %%
df.head()
# Out:
#             ID Filial     Cidade Tipo cliente  Genero       Linha produto  \
# 0  319-50-3348      B   Mandalay       Normal  Female  Home and lifestyle
# 1  390-80-5128      B   Mandalay       Member  Female   Health and beauty
# 2  523-38-0215      C  Naypyitaw       Normal    Male  Home and lifestyle
# 3  565-91-4567      B   Mandalay       Normal    Male   Health and beauty
# 4  829-34-3910      A     Yangon       Normal  Female   Health and beauty
#
#    Preco unitario  Quantidade  Taxa 5%     Total       Data   Hora  \
# 0           40.30           2   4.0300   84.6300  3/11/2019  15:30
# 1           19.15           1   0.9575   20.1075  1/28/2019  17:58
# 2           37.00           1   1.8500   38.8500   3/6/2019  13:29
# 3           10.75           8   4.3000   90.3000  3/15/2019  14:38
# 4           71.38          10  35.6900  749.4900  3/29/2019  19:21
#
#   Forma pagamento  Custo produto vendido  Margem bruta  Receita bruta  Rating
# 0         Ewallet                  80.60      4.761905         4.0300     4.4
# 1     Credit card                  19.15      4.761905         0.9575     9.5
# 2     Credit card                  37.00      4.761905         1.8500     7.9
# 3         Ewallet                  86.00      4.761905         4.3000     6.2
# 4            Cash                 713.80      4.761905        35.6900     5.7

# %% [markdown]
# #### b) Nessa etapa, busque gerar visualizações básicas do dataframe:
#            1) As cinco primeiras linhas;
#            2) As cinco últimas linhas;
#            3) Quantas linhas e colunas possuem no dataframe
#            4) Quais colunas existem no DataFrame qual o tipo de dados que cada coluna possui
#            5) Alguns dados estatísticos das variáveis quantitativas
#                - Média do valor total de cada compra
#                - Qual quantidade vendida mais é recorrente
#                - Receita total das vendas
#                - Menor e maior valor total de todas as vendas

# %%
# 1) As cinco primeiras linhas

# Código
df.head(5)
# Out:
#             ID Filial     Cidade Tipo cliente  Genero       Linha produto  \
# 0  319-50-3348      B   Mandalay       Normal  Female  Home and lifestyle
# 1  390-80-5128      B   Mandalay       Member  Female   Health and beauty
# 2  523-38-0215      C  Naypyitaw       Normal    Male  Home and lifestyle
# 3  565-91-4567      B   Mandalay       Normal    Male   Health and beauty
# 4  829-34-3910      A     Yangon       Normal  Female   Health and beauty
#
#    Preco unitario  Quantidade  Taxa 5%     Total       Data   Hora  \
# 0           40.30           2   4.0300   84.6300  3/11/2019  15:30
# 1           19.15           1   0.9575   20.1075  1/28/2019  17:58
# 2           37.00           1   1.8500   38.8500   3/6/2019  13:29
# 3           10.75           8   4.3000   90.3000  3/15/2019  14:38
# 4           71.38          10  35.6900  749.4900  3/29/2019  19:21
#
#   Forma pagamento  Custo produto vendido  Margem bruta  Receita bruta  Rating
# 0         Ewallet                  80.60      4.761905         4.0300     4.4
# 1     Credit card                  19.15      4.761905         0.9575     9.5
# 2     Credit card                  37.00      4.761905         1.8500     7.9
# 3         Ewallet                  86.00      4.761905         4.3000     6.2
# 4            Cash                 713.80      4.761905        35.6900     5.7

# %%
# 2) As cinco últimas linhas
# Código
df.tail(5)
# Out:
#                ID Filial     Cidade Tipo cliente  Genero  \
# 1095  122-61-9553      C  Naypyitaw       Normal  Female
# 1096  789-23-8625      B   Mandalay       Member    Male
# 1097  600-38-9738      C  Naypyitaw       Member    Male
# 1098  355-34-6244      B   Mandalay       Normal    Male
# 1099  595-27-4851      A     Yangon       Normal  Female
#
#                Linha produto  Preco unitario  Quantidade  Taxa 5%    Total  \
# 1095  Electronic accessories           51.32           9   23.094  484.974
# 1096     Fashion accessories           93.22           3      NaN  293.643
# 1097       Sports and travel           71.92           5   17.980  377.580
# 1098      Food and beverages           72.39           2    7.239  152.019
# 1099     Fashion accessories           54.28           7   18.998  398.958
#
#            Data   Hora Forma pagamento  Custo produto vendido  Margem bruta  \
# 1095  3/14/2019  19:33            Cash                 461.88      4.761905
# 1096  1/24/2019  11:45            Cash                 279.66      4.761905
# 1097  1/17/2019  15:05     Credit card                 359.60      4.761905
# 1098  1/13/2019  19:55     Credit card                 144.78      4.761905
# 1099  1/27/2019  18:05         Ewallet                 379.96      4.761905
#
#       Receita bruta  Rating
# 1095         23.094     5.6
# 1096         13.983     7.2
# 1097         17.980     4.3
# 1098          7.239     8.1
# 1099         18.998     9.3

# %%
# 3) Quantas linhas e colunas possuem no dataframe

# Código
print("Linhas: ", df.shape[0])
print("Colunas: ", df.shape[1])
# Out:
# Linhas:  1100
# Colunas:  17

# %%
# 4) Quais colunas existem no DataFrame qual o tipo de dados que cada coluna possui

# Código
print("Colunas: \n\n",df.columns,"\n\n\n")
print("Tipo de dados: \n\n",df.dtypes)
# Out:
# Colunas:
#
#  Index(['ID', 'Filial', 'Cidade', 'Tipo cliente', 'Genero', 'Linha produto',
#        'Preco unitario', 'Quantidade', 'Taxa 5%', 'Total', 'Data', 'Hora',
#        'Forma pagamento', 'Custo produto vendido', 'Margem bruta',
#        'Receita bruta', 'Rating'],
#       dtype='object')
#
#
#
# Tipo de dados:
#
#  ID                        object
# Filial                    object
# Cidade                    object
# Tipo cliente              object
# Genero                    object
# Linha produto             object
# Preco unitario           float64
# Quantidade                 int64
# Taxa 5%                  float64
# Total                    float64
# Data                      object
# Hora                      object
# Forma pagamento           object
# Custo produto vendido    float64
# Margem bruta             float64
# Receita bruta            float64
# Rating                   float64
# dtype: object

# %%
# 5) Alguns dados estatísticos das variáveis quantitativas
        # - Média do valor total de cada compra
        # - Qual quantidade vendida mais é recorrente
        # - Receita total das vendas
        # - Menor e maior valor total de todas as vendas

# Código
print("Média do valor total de cada compra: R$", round(df["Total"].mean(),2))
print("Quantidade vendida mais recorrente: ", df["Quantidade"].mode()[0]," unidades")
print("Receita total das vendas: R$", round(df["Total"].sum(),2))
print("Venda com menor valor: R$", df["Total"].min())
print("Venda com maior valor: R$", df["Total"].max())
# Out:
# Média do valor total de cada compra: R$ 326.9
# Quantidade vendida mais recorrente:  10  unidades
# Receita total das vendas: R$ 359594.08
# Venda com menor valor: R$ 10.6785
# Venda com maior valor: R$ 1042.65

# %% [markdown]
# #### c) Apague do DataFrame algumas colunas que não serão úteis para nossos exercícios e exibia o DataFrame para confirmar que elas foram excluídas
#          - "Invoice ID"
#          - "City"
#          - "Time"

# %%
df.drop(["ID", "Cidade","Hora"], axis=1, inplace=True)
df.head(5)
# Out:
#   Filial Tipo cliente  Genero       Linha produto  Preco unitario  Quantidade  \
# 0      B       Normal  Female  Home and lifestyle           40.30           2
# 1      B       Member  Female   Health and beauty           19.15           1
# 2      C       Normal    Male  Home and lifestyle           37.00           1
# 3      B       Normal    Male   Health and beauty           10.75           8
# 4      A       Normal  Female   Health and beauty           71.38          10
#
#    Taxa 5%     Total       Data Forma pagamento  Custo produto vendido  \
# 0   4.0300   84.6300  3/11/2019         Ewallet                  80.60
# 1   0.9575   20.1075  1/28/2019     Credit card                  19.15
# 2   1.8500   38.8500   3/6/2019     Credit card                  37.00
# 3   4.3000   90.3000  3/15/2019         Ewallet                  86.00
# 4  35.6900  749.4900  3/29/2019            Cash                 713.80
#
#    Margem bruta  Receita bruta  Rating
# 0      4.761905         4.0300     4.4
# 1      4.761905         0.9575     9.5
# 2      4.761905         1.8500     7.9
# 3      4.761905         4.3000     6.2
# 4      4.761905        35.6900     5.7

# %% [markdown]
# #

# %% [markdown]
# ### 2) Após entender do que o seu Data Set se trata, chegou a hora de realizar a limpeza de dados. Dessa forma, existem dois casos de "sujeira" dentro de um conjunto de dados:
#             1) NaN
#             2) Casos duplicados

# %% [markdown]
# #### a) Identifique quantos casos de NaN encontramos em cada uma das colunas e encontre um jeito de substituir esses valores. (Dica: Imposto = Preço total * 0.05)

# %%
print(df.isna().sum())
df["Taxa 5%"].fillna(df["Preco unitario"]*df["Quantidade"]*0.05,inplace=True)
df.isna().sum()
# Out:
# Filial                     0
# Tipo cliente               0
# Genero                     0
# Linha produto              0
# Preco unitario             0
# Quantidade                 0
# Taxa 5%                  163
# Total                      0
# Data                       0
# Forma pagamento            0
# Custo produto vendido      0
# Margem bruta               0
# Receita bruta              0
# Rating                     0
# dtype: int64
# Filial                   0
# Tipo cliente             0
# Genero                   0
# Linha produto            0
# Preco unitario           0
# Quantidade               0
# Taxa 5%                  0
# Total                    0
# Data                     0
# Forma pagamento          0
# Custo produto vendido    0
# Margem bruta             0
# Receita bruta            0
# Rating                   0
# dtype: int64

# %% [markdown]
# #### b) Identifique quantas linhas duplicadas existem na base de dados, exiba elas e, por fim, exclua-as do DataFrame

# %%
print("Linhas duplicadas: ",df.duplicated().sum())
display(df[df.duplicated()])
df.drop_duplicates(inplace=True)
print("Linhas duplicadas depois de apagar: ",df.duplicated().sum())
# Out:
# Linhas duplicadas:  100
#      Filial Tipo cliente  Genero           Linha produto  Preco unitario  \
# 138       B       Member    Male  Electronic accessories           18.93
# 171       C       Member    Male       Health and beauty           15.37
# 193       B       Member  Female      Food and beverages           20.01
# 217       B       Normal    Male       Health and beauty           87.87
# 243       C       Normal  Female  Electronic accessories           41.65
# ...     ...          ...     ...                     ...             ...
# 1060      A       Member  Female      Food and beverages           44.59
# 1062      B       Member  Female     Fashion accessories           17.87
# 1063      C       Normal  Female       Health and beauty           99.19
# 1067      B       Member    Male       Sports and travel           78.07
# 1094      B       Member    Male       Health and beauty           56.69
#
#       Quantidade  Taxa 5%     Total       Data Forma pagamento  \
# 138            6   5.6790  119.2590  2/10/2019     Credit card
# 171            2   1.5370   32.2770  3/16/2019            Cash
# 193            9   9.0045  189.0945   2/6/2019         Ewallet
# 217           10  43.9350  922.6350  3/29/2019         Ewallet
# 243           10  20.8250  437.3250  1/13/2019     Credit card
# ...          ...      ...       ...        ...             ...
# 1060           5  11.1475  234.0975  2/10/2019            Cash
# 1062           4   3.5740   75.0540  3/22/2019         Ewallet
# 1063           6  29.7570  624.8970  1/21/2019     Credit card
# 1067           9  35.1315  737.7615  1/28/2019            Cash
# 1094           9  25.5105  535.7205  2/27/2019     Credit card
#
#       Custo produto vendido  Margem bruta  Receita bruta  Rating
# 138                  113.58      4.761905         5.6790     8.1
# 171                   30.74      4.761905         1.5370     7.2
# 193                  180.09      4.761905         9.0045     4.1
# 217                  878.70      4.761905        43.9350     5.1
# 243                  416.50      4.761905        20.8250     5.4
# ...                     ...           ...            ...     ...
# 1060                 222.95      4.761905        11.1475     8.5
# 1062                  71.48      4.761905         3.5740     6.5
# 1063                 595.14      4.761905        29.7570     5.5
# 1067                 702.63      4.761905        35.1315     4.5
# 1094                 510.21      4.761905        25.5105     8.4
#
# [100 rows x 14 columns]
# Linhas duplicadas depois de apagar:  0
